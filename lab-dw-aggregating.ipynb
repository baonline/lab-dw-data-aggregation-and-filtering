# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv',usecols=list(range(1,26)))
df.head(1)
# Out:
#   Customer    State  Customer Lifetime Value Response Coverage Education  \
# 0  DK49336  Arizona               4809.21696       No    Basic   College
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/18/11         Employed      M   48029      Suburban
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    61                      7.0
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                             52                        0.0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   9  Corporate Auto  Corporate L3           Offer3
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size Vehicle Type
# 0         Agent               292.8  Four-Door Car      Medsize          NaN

# %%
#solving as query
df.query('total_claim_amount>1000 and response == "Yes"')
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 189    OK31456  California             11009.130490      Yes   Premium
# 236    YJ16163      Oregon             11009.130490      Yes   Premium
# 419    GW43195      Oregon             25807.063000      Yes  Extended
# 442    IP94270     Arizona             13736.132500      Yes   Premium
# 587    FJ28407  California              5619.689084      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10351  FN44127      Oregon              3508.569533      Yes  Extended
# 10373  XZ64172      Oregon             10963.957230      Yes   Premium
# 10487  IX60941      Oregon              3508.569533      Yes  Extended
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 10708  CK39096      Oregon              5619.689084      Yes   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
#solving as with loc
filter_claim = df['total_claim_amount']>1000
filter_marketing = df['response'] == 'Yes'
df.loc[filter_claim&filter_marketing]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 189    OK31456  California             11009.130490      Yes   Premium
# 236    YJ16163      Oregon             11009.130490      Yes   Premium
# 419    GW43195      Oregon             25807.063000      Yes  Extended
# 442    IP94270     Arizona             13736.132500      Yes   Premium
# 587    FJ28407  California              5619.689084      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10351  FN44127      Oregon              3508.569533      Yes  Extended
# 10373  XZ64172      Oregon             10963.957230      Yes   Premium
# 10487  IX60941      Oregon              3508.569533      Yes  Extended
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 10708  CK39096      Oregon              5619.689084      Yes   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
#solving with .groupby and .get_group
df.groupby(df['total_claim_amount']>1000).get_group(True).groupby('response').get_group('Yes')
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 189    OK31456  California             11009.130490      Yes   Premium
# 236    YJ16163      Oregon             11009.130490      Yes   Premium
# 419    GW43195      Oregon             25807.063000      Yes  Extended
# 442    IP94270     Arizona             13736.132500      Yes   Premium
# 587    FJ28407  California              5619.689084      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10351  FN44127      Oregon              3508.569533      Yes  Extended
# 10373  XZ64172      Oregon             10963.957230      Yes   Premium
# 10487  IX60941      Oregon              3508.569533      Yes  Extended
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 10708  CK39096      Oregon              5619.689084      Yes   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
#solving with pivot table 
pd.pivot_table(df.loc[filter_marketing],index=['policy_type','gender'],values='total_claim_amount',aggfunc='mean')
# Out:
#                        total_claim_amount
# policy_type    gender
# Corporate Auto F               433.738499
#                M               408.582459
# Personal Auto  F               452.965929
#                M               457.010178
# Special Auto   F               453.280164
#                M               429.527942

# %%
#solving with groupby
df.loc[filter_marketing].groupby(['policy_type','gender'])[['total_claim_amount']].mean()
# Out:
#                        total_claim_amount
# policy_type    gender
# Corporate Auto F               433.738499
#                M               408.582459
# Personal Auto  F               452.965929
#                M               457.010178
# Special Auto   F               453.280164
#                M               429.527942

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
states_500 = df['state'].value_counts()[df['state'].value_counts()>500].index

# %%
filter_states = df['state'].isin(states_500)
df[filter_states].groupby('state').size()
df[filter_states]['state'].value_counts()
pd.pivot_table(df[filter_states],index='state',columns='customer',aggfunc='count')
# Out:
#            coverage                                                          \
# customer    AA10041 AA11235 AA16582 AA30683 AA34092 AA35519 AA56476 AA69265
# state
# Arizona         NaN     NaN     NaN     NaN     NaN     1.0     2.0     NaN
# California      2.0     NaN     NaN     1.0     1.0     NaN     NaN     NaN
# Nevada          NaN     2.0     NaN     NaN     NaN     NaN     NaN     1.0
# Oregon          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Washington      NaN     NaN     1.0     NaN     NaN     NaN     NaN     NaN
#
#                                                                             \
# customer   AA71604 AA93585 AB13432 AB21519 AB23825 AB26022 AB31813 AB45325
# state
# Arizona        2.0     NaN     NaN     NaN     NaN     NaN     NaN     1.0
# California     NaN     1.0     1.0     1.0     1.0     NaN     NaN     NaN
# Nevada         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
df.groupby(['education','gender'])[['customer_lifetime_value']].agg(['max','min','median'])
# Out:
#                             customer_lifetime_value
#                                                 max          min       median
# education            gender
# Bachelor             F                  73225.95652  1904.000852  5640.505303
#                      M                  67907.27050  1898.007675  5548.031892
# College              F                  61850.18803  1898.683686  5623.611187
#                      M                  61134.68307  1918.119700  6005.847375
# Doctor               F                  44856.11397  2395.570000  5332.462694
#                      M                  32677.34284  2267.604038  5577.669457
# High School or Below F                  55277.44589  2144.921535  6039.553187
#                      M                  83325.38119  1940.981221  6286.731006
# Master               F                  51016.06704  2417.777032  5729.855012
#                      M                  50568.25912  2272.307310  5579.099207

# %%
df.groupby(['education','gender'])[['customer_lifetime_value']].describe().round(2)
# Out:
#                             customer_lifetime_value                    \
#                                               count     mean      std
# education            gender
# Bachelor             F                       1700.0  7874.27  6614.11
#                      M                       1572.0  7703.60  6658.46
# College              F                       1608.0  7748.82  6678.30
#                      M                       1596.0  8052.46  6716.96
# Doctor               F                        200.0  7328.51  6930.56
#                      M                        201.0  7415.33  5460.94
# High School or Below F                       1590.0  8675.22  7497.85
#                      M                       1556.0  8149.69  7190.62
# Master               F                        475.0  8157.05  6621.77
#                      M                        412.0  8168.83  7362.16
#
#
#                                  min      25%      50%      75%       max
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %%
from datetime import timedelta
timedelta()
# Out:
# datetime.timedelta(0)

# %%
df['days_since_policy_inception'] = (df['months_since_policy_inception']*(365/12)).apply(pd.Timedelta,unit='D')

# %%
df['policy_creation'] = pd.to_datetime(df['effective_to_date'])-df['days_since_policy_inception']
# Out:
# C:\Users\baort\AppData\Local\Temp\ipykernel_23548\3641605040.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['policy_creation'] = pd.to_datetime(df['effective_to_date'])-df['days_since_policy_inception']

# %%
df['month'] = df['policy_creation'].dt.month

# %%
pd.pivot(df,index='state',columns='month',values='number_of_policies',aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 pd.pivot(df,index='state',columns='month',values='number_of_policies',aggfunc='sum')
#
# TypeError: pivot() got an unexpected keyword argument 'aggfunc'

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9
